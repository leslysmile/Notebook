# %% [markdown]
# # This is jupyter notebook in the github codespaces
#
# ## We want to learn jupyter
#
# 1. This is number 1
# 2. This is number 2
#
# **Auto-Numbering**
# ![image.png](attachment:4b65fda7-714c-43d1-91c3-22a5fb291a6e.png)

# %% [markdown]
# ## this is test of keyboard shortcut
#
# Esc -> Command mode
# a - insert a cell above
# b - insert a cell below
# m - markdown
# y - code

# %%
print('Hello world!')
x = 10
print(x + 1)
# Out:
# Hello world!
# 11

# %% [markdown]
# ## Import Libraries
#
# The default container image that's used by GitHub Codespaces includes a set of machine learning libraries that are preinstalled in your codespace. For example, Numpy, pandas, SciPy, Matplotlib, <label style="background-color: red">seaborn</label>, scikit-learn, Keras, PyTorch, Requests, and Plotly
# While if you run the script below in a local machine, you need to install the library.e.g. <label style="color: red">pip install seaborn</label>

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.set_theme(style="darkgrid")
iris = sns.load_dataset("iris")

# Set up the figure
f, ax = plt.subplots(figsize=(8, 8))
ax.set_aspect("equal")

# Draw a contour plot to represent each bivariate density
sns.kdeplot(
    data=iris.query("species != 'versicolor'"),
    x="sepal_width",
    y="sepal_length",
    hue="species",
    thresh=.1,
)
# Out:
# <Axes: xlabel='sepal_width', ylabel='sepal_length'>

# %% [markdown]
# ### This chart looks great.
# **really great**

# %% [markdown]
# # Conclusion
